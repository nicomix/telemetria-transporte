# %%
import pandas as pd

# %%
filepath = "../telemetria.csv"
data_raw = pd.read_csv(filepath)

# %%
data_raw.head()
# Out:
#                             tracking_id vehicle_id company_id  route_id  \
# 0  61781b27-58b5-49a1-a4b9-a5365b98e050   VEH_0003    EMP_003  RUTA_007
# 1  427e574c-1d4b-440f-bb0b-d06d84200bf0   VEH_0028    EMP_003  RUTA_018
# 2  dcbd2c8a-3b4d-429a-8af1-352f964c53f4   VEH_0156    EMP_001  RUTA_007
# 3  e883266c-e209-4280-96d1-bb4079754c17   VEH_0035    EMP_005  RUTA_010
# 4  80df3b8f-896f-4def-a64d-c476d47ea7e0   VEH_0237    EMP_002  RUTA_013
#
#          driver_id           event_time          received_at  latitude  \
# 0  EMP_003_DRV_048  2024-03-04 13:08:26  2024-03-04 13:08:32  2.620703
# 1  EMP_003_DRV_037  2024-03-05 18:07:20  2024-03-05 18:07:24  9.252828
# 2  EMP_001_DRV_067  2024-03-04 18:05:01  2024-03-04 18:05:05  2.888177
# 3  EMP_005_DRV_079  2024-03-05 15:36:09  2024-03-05 15:36:15  9.828977
# 4  EMP_002_DRV_052  2024-03-05 01:55:45  2024-03-05 01:55:51  4.358705
#
#    longitude  speed  fuel_level  battery_level  odometer_km  passenger_count  \
# ...
